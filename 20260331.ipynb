# %% [markdown]
# ### 14시 부터 참가

# %% [markdown]
# ### 데이터 가공

# %% [markdown]
# ### 도시명 입력후 위도 반환

# %%
# 미션
# 도시명을 입력하면 위도를 반환하는 함수 만들기

def predict_best_meteor_shower_viewing(city):
    #입력된 도시의 위도 정보 조회
    latitude = cities.loc[cities['city']] == city, 'latitude'],
    #반환된 위도에서 관측 가능한 별자리 조회
    constellattions = constellations.loc[(constellations['latitudeend'] <= 37.55) & (constellations['latitudestart'] >= 37.55), 'constellations'].to_listt

    return latitusde, constellation_list
# Out:
#   Cell In[1], line 6
#     latitude = cities.loc[cities['city']] == city, 'latitude'],
#                                                              ^
# SyntaxError: unmatched ']'

# %%
# 37.55
# constellations['latitudestart'] >= 37.55
constellations.loc[(constellations['latitudeend'] <= 37.55) & (constellations['latitudestart'] >= 37.55), 'constellations'].to_listt()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 constellations
#
# NameError: name 'constellations' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 도시명을 입력하면 위도와 별자리 리스트와 메세지를 반환하는 함수
# 입력한 도시 정보가 없을 경우의 멘트 "~에서는 별자리 관측이 불가능합니다."
# 해당 도시에서 조회된 별자리가 있을 경우의 멘트  "~에서 별자리 관측이 가능합니다."

def predict_best_meteor_shower_viewing(city):

    return latitude, constellations_list, meteor_shower_string


def predict_best_meteor_shower_viewing(city):
    meteor_shower_string = ''

    # 입력된 도시 정보가 존재하지 않을 경우
    if city not in cities.values:
        meteor_shower_string = f'아쉽지만 {city}에서는 별자ㅏ리 서비스가 되지 않습니다.'
        return meteor_shower_string
    
    #입력된 도시의 위도 정보 조회
    latitude = cities.loc[cities['city'] == city, 'latitude'].iloc[0]

    #반환된 위도에서 관측이 가능한 별자리 조회
    constellations_list = constellations.loc[(constellation['latutydestart'] >= latitude) & (constellations['latitudeend'] <= latitude), 'constellation'].to_list()
    
    # 반환된 위도에서 관측 가능한 별자리가 조재 하지 않을경우
    if not constellations_list:
        meteor_shower_string = f'아쉽지만 {city}에서는 별자리 관측이 불가능합니다.'
        return meteor_shower_string
    
    meteor_shower_string = f'{city}에서는 별자리 관측이 가능합니다.\n\n'

    return latitude, constellations_list, meteor_shower_string, 시각 날짜, 유성우 끝날짜

    for i in constellations_list:
        meteor_shower = meteor_showers.loc[meteor_showers['radiant'] == i, 'name'].iloc[0]
        meteor_showers_startdate =meteor_showers.loc[meteor_showers['radiant'] == i, 'startdate'].iloc[0]
        meteor_showers_enddate =meteor_showers.loc[meteor_showers['radiant'] == i, 'enddate'].iloc[0]

        moon_phaes_list
        moon_phase_list = meteor_showers.loc[(moon_phases['date'] >= meteor_showers_startdate) & (moon_phases ['date'] <= meteor_shower_enddate)]
        best_moon_date = moon_phas_list.loc[moon_phase_list['percentage'].idxmin()]['date']

        meteor_showers_string += f'{meteor_shower} 유성우는 {i}별자리 방향으로 {best_moon_date.to_pydatetime().strftime("%Y년 %m월 %d일")}에 가장 잘 관측 가능합니다.\n'
    return meteor_showers_string

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
wellington = predict_best_meteor_shower_viewing('wellington')
wellington

# %%
cities.loc[cities['city'] == 'anyang', 'latitude'].iloc[0]
"'anyang'에서는 별자리 서비스가 되지 않습니다."

# %%
'Anyang' in cities.values
'Seoul' in cities.values

# %%
cities.values #도시 이름 분리

# %%
city = 'Anyang'

if city not in cities.values:
    print(f'아쉽지만 {city}에서는 별자리 서비스를 지원하지 않습니다.')

# %%
meteor_showers.heade

# %%
# seoul -> 위도 정보 -> 별자리[] -> 유성우, 유성우 시각 날짜, 유성우 끝날짜

['Lyra','Aquarius', 'Orion', 'Perseus']
'Aquarius' -> 유성우, 유성우 시각 날짜, 유성우 끝날짜
'Orion' -> 유성우, 유성우 시각 날짜, 유성우 끝날짜

# %%
meteor_showers['radiant'] == 'Lyra'

# %%
for i in ['Lyra','Aquarius', 'Orion', 'Perseus']:
     
    meteor_showers = meteor_showers.loc[meteor_showers['radiant'] == 'Lyra','name'].iloc[0]
    meteor_showers_startdate = meteor_showers.loc[meteor_showers['radiant'] == 'Lyra','startdate'].iloc[0]
    meteor_showers_enddate = meteor_showers.loc[meteor_showers['radiant'] == 'Lyra','enddate'].iloc[0]
    print(meteor_showers, meteor_showers_startdate, meteor_showers_enddate)

# %%
meteor_showers

# %%
# meteor_showers_startdate -> 2026년 7월 14일
meteor_showers_startdate.to_pydatetime().strftime('%Y년 %m월 %d일')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 달 위상의 최소값(달에서 반사되는 빛의 최소량)을 찾을 수 있습니다. 이 예측 함수에서는
# 첫번째 날짜만 확인합니다.

moon_phase_list = moon_phaes.loc[('date') >= meteor_showers_startdate & (moon_phaes['date'] <= meteor_showers_enddate)]
moon_phase_list.head

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 가장 어두운 날 찾기
moon_phase_list['percentage'].idxmin() # 가장 백분율이 적은 행 인덱스 변환

# %%
best_moon_date = moon_phase_list.loc[moon_phase_list['percentage'].idxmin()]['date']
best_moon_date

# %%
for i in ['Lyra', 'Aquarius', 'Orion', 'Perseus']:
    meteor_shower = meteor_showers.loc[meteor_showers['radiant'] == i, 'name'].iloc[0]
    meteor_showers_startdate =meteor_showers.loc[meteor_showers['radiant'] == i, 'startdate'].iloc[0]
    meteor_showers_enddate =meteor_showers.loc[meteor_showers['radiant'] == i, 'enddate'].iloc[0]
    print(meteor_shower, meteor_showers_startdate, meteor_showers_enddate)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
moon_phase_list = meteor_showers.loc[(moon_phases['date'] >= meteor_showers_startdate) & (moon_phases ['date'] <= meteor_shower_enddate)]
best_moon_date = moon_phas_list.loc[moon_phase_list['percentage'].idxmin()]['date']

meteor_showers_string += f'{meteor_shower} 유성우는 {i}별자리 방향으로 {best_moon_date.to_pydatetime().strftime("%Y년 %m월 %d일")}에 가장 잘 관측 가능합니다.\n'
return meteor_showers_string

# %%
print()

# %%
print()

# %%
print()

# %% [markdown]
# ### 항아 유성우 데이터 추가

# %%
# 항아 유성우 데이터 추가하기
change_meteor_shower = {'name': "chang\'e",'radiant' : 'Draco', 'destmonth': 'october', }

# %%
def

# %%
def predict_best_meteor_shower_viewing(city):





    return meteor_showers_string

# %%
print(predict_best_meteor_shower_viewing('Beijing'))

# %% [markdown]
# ### 시각화

# %%
import matplotlib.pyplot as plt
import numpy as up

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt

plt.rc('font', family = 'malgun Gothic')
plt.rd('axes', unicode_minus=False)

plt.figure(figsize = (10, 5))

plt.barh(meteor_showers['name'], meteor_showers['enddate'] - meteor_showers['startdate'], left = meteor_shower['startdate'], color='skyblue')

plt.title('유성우 발생기간')
plt.xlabel('날짜', fontsize=12)
plt.ylabel('유성우', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(10,5))

plt.plot(moon_phases['date'], moon_phases['percentage'], color='gold')

plt.title('달의 위상')
plt.xlabel('날짜', fontsize=12)
plt.ylabel('달의 밝기', fontsize=12)
plt.grid(True, linestyle='--',alpha=0.6)
plt.show()

# %%
# 인선미 강사 예시

import matplotlib.pyplot as plt
 
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
 
plt.figure(figsize=(10, 5))
 
plt.barh(meteor_showers['name'],  meteor_showers['enddate'] - meteor_showers['startdate'], left =meteor_showers['startdate'], color='skyblue' )
 
plt.title('유성우 발생기간')
plt.xlabel('날짜', fontsize=12)
plt.ylabel('유성우', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
 
plt.figure(figsize=(10, 5))
 
plt.plot(moon_phases['date'], moon_phases['percentage'], color='gold')
 
plt.title('달의 위상')
plt.xlabel('날짜', fontsize=12)
plt.ylabel('달의 밝기', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
