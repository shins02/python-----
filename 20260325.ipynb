# %% [markdown]
# ### 함순와 변수의 효력 범위

# %% [markdown]
# ### map 함수

# %%
a = 1
def vartest(a):
    a = a + 1

# %%
vartest(a)
print(a)
# Out:
# 1

# %%
def var_test(a):
    a = a + 1

# %%
var_test(3)
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 var_test(3)
# ----> 2 print(a)
#
# NameError: name 'a' is not defined

# %%
a = 1
def vartest(a):
    a = a + 1
    return a

# %%
vartest(a)
print(a)
# Out:
# 2

# %%
a = 1
def vartest():
    global a
    a = a + 1

# %%
vartest()
print(a)
# Out:
# 14

# %%
mylist = [1, 2, 3, 4, 5] # -> 2배

result = []
for i in mylist:
    result.append(i*2)

result
# Out:
# [2, 4, 6, 8, 10]

# %%
def mul_twice(n):
    return n*2
list(map(mul_twice, mylist)) # [1,2,,3,4,5]
# Out:
# [2, 4, 6, 8, 10]

# %%
# 실습

f = (3.14, -5.625, 100.4, 25.8)

list(map(round,f))
# Out:
# [3, -6, 100, 26]

# %%
# 내가 하려던거

def add_ms (n):
    return 
list(map(round,f))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 5
#       3 def add_ms (n):
#       4     return
# ----> 5 list(map(round,f))
#
# NameError: name 'f' is not defined

# %%
round(5.36)
# Out:
# 5

# %% [markdown]
# ### zip 함수

# %%
name = ['지민', '윤기', '달기']
scores = [98, 95, 88]

# %%
# 사용 1 예시
for i in zip(name, scores):
    print (i)
# Out:
# ('지민', 98)
# ('윤기', 95)
# ('달기', 88)

# %%
# 사용 2 예시
for name, scores in zip(name, scores):
    print (f"{name}(이)는 {scores}점 입니다.")
# Out:
# 지민(이)는 98점 입니다.
# 윤기(이)는 95점 입니다.
# 달기(이)는 88점 입니다.

# %%
# mesion

r = (52, 255, 39, 132)
g = (19, 63, 227, 197)
b = (0, 68, 255, 187)

img = list(zip(r,g,b))
print(img)
# Out:
# [(52, 19, 0), (255, 63, 68), (39, 227, 255), (132, 197, 187)]

# %%
list(zip('abcdefg',range(3), range (4)))
# Out:
# [('a', 0, 0), ('b', 1, 1), ('c', 2, 2)]

# %%
range(3)
# Out:
# range(0, 3)

# %% [markdown]
# ### enumerate 함수

# %%
fruits = ['apple', 'banana', 'cherry']

# 1
list(enumerate(fruits))

# 2
for i in enumerate(fruits):
    print (i)
# 3
for index, fruits in enumerate(fruits, 1):
    print (index, fruits)
# Out:
# (0, 'apple')
# (1, 'banana')
# (2, 'cherry')
# 1 apple
# 2 banana
# 3 cherry

# %%
print (*enumerate(fruits, 1))
# Out:
# (1, 'c') (2, 'h') (3, 'e') (4, 'r') (5, 'r') (6, 'y')

# %%
# 미션?
f = ['apple', 'banana', 'cherry']

for index, f in enumerate(f,1):
    tag = print (index, f, end= ' ')

print(tag)
# Out:
# 1 apple 2 banana 3 cherry None

# %%
f = ['apple', 'banana', 'cherry']

# %%
# 인선미 강사 예시
dict(enumerate(f,1))
# Out:
# {1: 'apple', 2: 'banana', 3: 'cherry'}

# %% [markdown]
# ### filter

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = [8, 3, 2, 10, 15, 7, 1, 0, 11]
# filter 함수를 이용해서 짝수만 필터링

# %%
result = []
for i in a:
    if i > 5 and i < 10:
        result.append(i)
result
# Out:
# [8, 7]

# %%
# 내가 시도 한것

result = []
re = []
for i in a:
    if i % 2 == 0 :
        result.append(i)
    elif i % 2 != 0:
        re.append(i)
result
# Out:
# [8, 2, 10, 0]

# %%
# 인선미 강사 예시

def is_even(x):
    return x % 2 == 0

list(filter(is_even,a))
# Out:
# [8, 2, 10, 0]

# %% [markdown]
# ### 람다 함수

# %%
# 예시

def add_one(n):
    return n+1

# %%
add_one(5)
# Out:
# 6

# %%
# 예시
(lambda x: x+1)(3)
# Out:
# 4

# %%
func = (lambda x: x+1)

# %%
func(5)
# Out:
# 6

# %%
a = [8, 3, 2, 10, 15, 7, 1, 0, 11]
 
# filter 함수를 이용해서 짝수만 필터
# def is_even(x):
#    return x % 2 == 0

list(filter(lambda x: x % 2 == 0 , a))
# Out:
# [8, 2, 10, 0]

# %%
#def mul_twice(n):
#    return n * 2
 
list(map(lambda x: x * 2, mylist)) # [1, 2, 3, 4, 5]
# Out:
# [2, 4, 6, 8, 10]

# %%
# 사용 문제 해결

numbers = [1, 2, 3, 4]
squared = list(map(lambda x: x ** 2,numbers))
print(squared)
# Out:
# [1, 4, 9, 16]

# %%
# 사용 문제 해결

numbers = [1, 2, 3, 4]
even_numbers = list(filter(lambda x: x % 2 == 0, numbers))
print(even_numbers)
# Out:
# [2, 4]

# %%
# 내가 예상한 답

points = [(1, 2), (3, 4), (5, 1)]
sorted_points = sorted(points, reverse=True)
print(sorted_points)
# Out:
# [(5, 1), (3, 4), (1, 2)]

# %%
# 인선미 강사 예시

points = [(1, 2), (3, 4), (5, 1)]
sorted_points = sorted(points, key= lambda x : (x[1], x[0]))
print(sorted_points)
# Out:
# [(5, 1), (1, 2), (3, 4)]

# %%
# 덮어 씌우기

points = sorted(points, key= lambda x : (x[1], x[0]))

# %%
# 연습용 mesion
'''
등수구하기
 
영어 점수와 수학 점수의 평균 점수를 기준으로 학생들의 등수를 매기려고 합니다. 
영어 점수와 수학 점수를 담은 2차원 리스트 score가 주어질 때, 
영어 점수와 수학 점수의 평균을 기준으로 매긴 등수를 담은 리스트를 return하도록 함수를 만들어주세요
 
[[80, 70], [90, 50], [40, 70], [50, 80]] -> [1, 2, 4, 3]
[[80, 70], [70, 80], [30, 50], [90, 100], [100, 90], [100, 100], [10, 30]] -> [4, 4, 6, 2, 2, 1, 7]
'''

score = [[80, 70], [90, 50], [40, 70], [50, 80]]

rank = (score, lambda x: x[0] + x[1] % 2)
print(list(rank))

def avl(x):
    
    return lv
print(avl)
# Out:
# [[[80, 70], [90, 50], [40, 70], [50, 80]], <function <lambda> at 0x0000018C1664E520>]
# <function avl at 0x0000018C16661260>

# %%
# 인선미 강사 예시

score = [[80, 70], [90, 50], [40, 70], [50, 80]]

def rank (score):
    avg = [(i + j) / 2  for i, j in score ]
    # avg = [sum(s)/len(s) for s in score] 대량 과목 가능함
    avg_sort = sorted(avg, reverse=True)
    result = [ avg_sort.index(i) + 1 for i in avg]
    return result

# %%
avg_sort
# Out:
# [75.0, 70.0, 65.0, 55.0]

# %%
소수판별 함수 is_prime()
mylist = [1, 2, 3, 4, 5, 6, 7, 8, 9]
list(filter(is_prime, mylist))
[2, 3, 5, 7]

def is_prime()
    for i in mylist :
        i %% = 2
    print('소수')
    list(filter(mylist,))
    return

# %%
# 인선미 강사 예시
'''
mylist = [1, 2, 3, 4, 5, 6, 7, 8, 9]
list(filter(is_prime, mylist))
[2, 3, 5, 7]
'''
mylist = [1, 2, 3, 4, 5, 6, 7, 8, 9]


def is_prime(num) :
    if num < 2:
        return False
    for i in range(2, num):
        if num % i == 0:
            return False
    return True

# %%
## 최재혁씨 예시

score1 = [[80, 70], [90, 50], [40, 70], [50, 80]]
score2 = [[80, 70], [70, 80], [30, 50], [90, 100], [100, 90], [100, 100], [10, 30]]
 
def func1(x):
    result = [sum(i) / len(i) for i in x]
    sort_result = sorted(enumerate(result, 1), key=lambda x: x[1], reverse=True)
 
    ranks = {}
    current_rank = 0
    prev_score = None
 
    for idx, (num, avg) in enumerate(sort_result, 1):
        if avg != prev_score:
            current_rank = idx
        ranks[num] = current_rank
        prev_score = avg
    return [ranks[i] for i in range(1, len(x) + 1)]
 
print(func1(score1))
print(func1(score2))
# Out:
# [1, 2, 4, 3]
# [4, 4, 6, 2, 2, 1, 7]

# %%
# 김민영씨 예시
# 약수 수량 정리

mylist = [1,2,3,4,5,6,7,8,9]

def is_prime(n):
    cnt = 0
    for i in range(1,n):
        if n % i == 0:
            cnt += 1
    if cnt == 1 :
        print(n)

list(filter(is_prime, mylist))
# Out:
# 2
# 3
# 5
# 7
# []

# %% [markdown]
# ### 모듈

# %%
import random

# %%
random.randint(1,45)
# Out:
# 44

# %%
import random as r

r.randint(1,45)
r.randrange(1,5)
# Out:
# 4

# %%
from random import randint, randrange

randint(1,45)
randrange(1,45)
# Out:
# 13

# %%
from random import *
from math import *
from numpy import*

randint (1,5)
randrange (1,5)
sample ([1,2,3],1)
# Out:
# [3]

# %% [markdown]
# ### 패키지

# %%
# 모듈미션 -> 로또 번호 추첨기

set (num = [])

while True :
    import random as r
    r.randint(1,45)
    num = input(r.randint)
    


else:
    print ("")
    break


list(set())
print("이번주 행운의 번호: ")

# %%
# 인선미 강사 예시

import random as r

result = []

while len(result) < 6:
    num = r.randint(1,45)
    if num not in result :
        result.append(num)

print('오늘의 추천 번호:')
result
# Out:
# 오늘의 추천 번호:
# [28, 14, 3, 40, 18, 19]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 사용자 모듈

# %%
import mymodule as mm
import importlib # 중간에 끊기는것을 다시 리로드 하는 코드

importlib.reload(mm) # 여기서 재 로딩


print(mm.my_add(3, 4))
print(mm.my_sub(1, 7))
# Out:
# mymodule 안에서의__name__: mymodule
# 7
# -6

# %%
import mypackage.calc_tool

mypackage.calc_tool.my_mul(11,3)
# Out:
# 14

# %%
from mypackage import text_tool
text_tool.my_greet("박지민")
# Out:
# '박지민님 안녕?'

# %%
import mypackage
mypackage.calc_tool.my_mul(2,3)
# Out:
# 5

# %%
mypackage.text_tool.my_greet('해장국')
# Out:
# '해장국님 안녕?'

# %%
import mypackage
import importlib

importlib.reload(mypackage)

mypackage.my_mul(5,5)
# Out:
# 10

# %%
num = "hello"

# %%
print(type(num))
# Out:
# <class 'str'>

# %% [markdown]
# ### 클래스

# %% [markdown]
# num.

# %%
class person :
    population = 0 # 클래스 변수 (공유)
    def __init__(self, name, age):
        # 초기화 루틴
        self.name = name # 인스턴수 변수
        self.age = age
        person.population += 1

    def walk(self):
        print(f"{self.name}이 걸어가요")

# %%
myname, my_func(),myFucn()

# %%
person01 = person('박지민', 31)

# %%
print(type(person01))
# Out:
# <class '__main__.person'>

# %%
person.population
# Out:
# 3

# %%
person01.age
# Out:
# 31

# %%
person01.walk()
# Out:
# 박지민이 걸어가요

# %%
person02 = person('해장국', 30)

# %%
person02.walk()
# Out:
# 해장국이 걸어가요

# %%
# 상속

class newperson(person):
    # 기능 확장
    def fiy(self):
        print(f"{self.name}이(가) 날고 있어요!!")

    def walk(self):
        print(f"{self.name}이(가) 아주 빠르게 걸어가요")
    
    # 수영기능 추가
    def swim(self):
        print(f"{self.name}이(가) 수영하고 있어요")

# %%
person03 = newperson('정명호', 43)

# %%
person03.fiy()
# Out:
# 정명호이(가) 날고 있어요!!

# %%
person03.walk()
# Out:
# 정명호이(가) 아주 빠르게 걸어가요

# %%
person03.swim()
# Out:
# 정명호이(가) 수영하고 있어요

# %%
person.population
# Out:
# 3

# %% [markdown]
# ### python 정리

# %%
# 옵션 1. 코드 (문법 복습용) -> 결과물
# 옵션 2. 클래스
# 옵션 3. 자유롭게

# %%
# 옵션 1 문법 복습용

a = str('*')

for i in range(1,10,2):
    print( i * a)
# Out:
# *
# ***
# *****
# *******
# *********

# %%
# 옵션 1 문법 복습용

i = int(input('숫자 입력 : '))


while 1 <= i :
    print(f"{i-1}th python")
    i -= 1
# Out:
# 4th python
# 3th python
# 2th python
# 1th python
# 0th python

# %%
# 옵션 1 문법 복습용

ap = ['배추김치', '총각김치', '굴김치','나박김치', '배추김치']
ap

ar = list(set(ap))
ar.sort()

ap
# Out:
# ['배추김치', '총각김치', '굴김치', '나박김치', '배추김치']

# %%
# 옵션 1 문법 복습용

def say_hello(num):
    print('hello')

say_hello(5)
# Out:
# hello

# %% [markdown]
# ### tutle

# %%
# 박성진 10번 예시

from turtle import *
color('blue', 'black')
begin_fill()
while True:
    forward(200)
    left(170)
    if abs(pos()) < 1:
        break
end_fill()
done()
